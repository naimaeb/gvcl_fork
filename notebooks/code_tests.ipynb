# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
# %load_ext autoreload
# %autoreload 2


# %run ../src/run.py --help
# Out:
# usage: run.py [-h] [--seed SEED] --experiment
#               {mnist2,pmnist,cifar,mixture,easy-chasy,hard-chasy,smnist}
#               --approach
#               {random,sgd,sgd-frozen,lwf,lfl,ewc,imm-mean,progressive,pathnet,imm-mode,sgd-restart,ewc2,ewc-film,joint,hat,hat-test,gvcl,vcl,vclf,gvclf}
#               [--regularizer {kl_g,re_g,kl_qg,re_qg}] [--output OUTPUT]
#               [--nepochs NEPOCHS] [--lr LR] [--parameter PARAMETER]
#               [--ntasks NTASKS] [--use-best-hyperparams USE_BEST_HYPERPARAMS]
#
# xxx
#
# options:
#   -h, --help            show this help message and exit
#   --seed SEED           (default=0)
#   --experiment {mnist2,pmnist,cifar,mixture,easy-chasy,hard-chasy,smnist}
#                         (default=)
#   --approach {random,sgd,sgd-frozen,lwf,lfl,ewc,imm-mean,progressive,pathnet,imm-mode,sgd-restart,ewc2,ewc-film,joint,hat,hat-test,gvcl,vcl,vclf,gvclf}
#                         (default=)
#   --regularizer {kl_g,re_g,kl_qg,re_qg}
# ...

# %%
# %run ../src/dataloaders/hasy_utils.py

# %%
# %run ../src/run.py --experiment easy-chasy --approach hat --seed 3
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/BIFOLD_work/CL_curved/gvcl_fork/src/run.py:192
#     188 ########################################################################################################################
#     189
#     190 # Load
#     191 print('Load data...')
# --> 192 data,taskcla,inputsize=dataloader.get(seed=args.seed)
#     193 if args.ntasks != -1:
#     194     taskcla = taskcla[:args.ntasks]
#
# File ~/BIFOLD_work/CL_curved/gvcl_fork/src/dataloaders/easy_chasy.py:43, in get(seed, pc_valid)
# ...

# %%
import os
cwd = os.getcwd()

# %%
import numpy
print(numpy.__version__)
